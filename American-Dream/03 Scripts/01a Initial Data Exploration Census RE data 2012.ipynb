# %% [markdown]
# # 01 Importing Libraries

# %% [markdown]
# # 02 Creating Dataframe

# %% [markdown]
# # 03 Initial Data Description

# %% [markdown]
# # 04 Removing Duplicates

# %% [markdown]
# # 05 Addressing Missing Values

# %% [markdown]
# # 06 Creating Data File for Project

# %% [markdown]
# ## 01 Importing Libraries

# %%
# Import Analysis Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02 Creating Dataframe

# %%
# Defining the main project path
proj = r'C:\Users\bfd_6\Documents\Career Foundry Project\Course Part 2\A6 Adv Analytics and Dashboards\Real Estate Project'

# %%
# Creating a data frame for the 2022 dataset
df_re = pd.read_excel(os.path.join(proj, '02 Data', 'Original Data', 'big_re_data_2012.xlsx'))

# %% [markdown]
# ## 03 Initial Data Description

# %%
df_re.shape
# Out:
# (3221, 84)

# %%
df_re.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3221 entries, 0 to 3220
# Data columns (total 84 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   geo_id                            3221 non-null   object
#  1   us_county                         3221 non-null   object
#  2   2012 total housing units          3221 non-null   int64
#  3   2012 occupied housing units       3221 non-null   int64
#  4   2012 vacant housing units         3221 non-null   int64
#  5   2012 num_units -1_detached        3221 non-null   int64
#  6   2012 num units-1_attached         3221 non-null   int64
#  7   2012 2 units                      3221 non-null   int64
#  8   2012 3-4 units                    3221 non-null   int64
#  9   2012 5-9 units                    3221 non-null   int64
#  10  2012 10-19 units                  3221 non-null   int64
#  11  2012 20+ units                    3221 non-null   int64
# ...

# %%
pd.set_option('display.max_columns', None)
df_re.describe().map(lambda x: f"{x:0,.3f}")
# Out:
#       2012 total housing units 2012 occupied housing units  \
# count                3,221.000                   3,221.000
# mean                41,334.799                  36,151.626
# std                121,307.683                 109,389.138
# min                     70.000                      35.000
# 25%                  5,505.000                   4,308.000
# 50%                 12,193.000                   9,847.000
# 75%                 30,052.000                  24,998.000
# max              3,441,416.000               3,218,511.000
#
#       2012 vacant housing units 2012 num_units -1_detached  \
# count                 3,221.000                  3,221.000
# mean                  5,183.173                 25,530.258
# std                  13,445.804                 64,683.104
# min                      35.000                     35.000
# 25%                     907.000                  4,072.000
# 50%                   1,931.000                  8,722.000
# ...

# %%
# Looking for columns with mixed data types
for col in df_re.columns.tolist():
    weird = (df_re[[col]].map(type) != df_re[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_re[weird]) > 0:
        print(col)
# Out:
# 2012 no full bathroom
# 2012 no landline available

# %% [markdown]
# There are two fields with mixed data types.

# %% [markdown]
# ## 04 Removing Duplicates

# %%
df_dupes = df_re[df_re.duplicated()]

# %%
print(df_dupes)
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# There are no duplicate rows in the dataframe. The dataframe is empty.

# %% [markdown]
# ## 05 Addressing Missing Values

# %%
pd.set_option('display.max_rows', None)
df_re.isnull().sum()
# Out:
# geo_id                              0
# us_county                           0
# 2012 total housing units            0
# 2012 occupied housing units         0
# 2012 vacant housing units           0
# 2012 num_units -1_detached          0
# 2012 num units-1_attached           0
# 2012 2 units                        0
# 2012 3-4 units                      0
# 2012 5-9 units                      0
# 2012 10-19 units                    0
# 2012 20+ units                      0
# 2012 mobile home                    0
# 2012 boat_rv_van_etc                0
# 2012 built 2010+                    0
# 2012 built 2000-2009                0
# 2012 built 1990-1999                0
# 2012 built 1980 -1989               0
# 2012 built 1970-1979                0
# 2012 built 1960-1969                0
# 2012 built 1950-1959                0
# 2012 built 1940-1949                0
# 2012 built before 1940              0
# 2012 1 room                         0
# 2012 2 rooms                        0
# ...

# %% [markdown]
# There are no missing values in the dataframe

# %% [markdown]
# ## 06 Creating Data File for Project

# %%
# Exporting pkl file to prepared data folder for the products data set with no dups or missing values
df_re.to_pickle(os.path.join(proj, '02 Data', 'Prepared Data', 'real_estate_data_2012.pkl'))
